# %% [markdown]
# ![image.png](attachment:image.png)
# <font color=green>Student Name: Mohd Zamani Bin Abu Bakar</font> <br />
# <font color=green>Student ID  : 17173342 / WQD190021</font> <br />
#
# **_CONTENTS_** <br />
# 1. PROJECT INTRODUCTION
# 2. PROJECT EXECUTION
# 3. CONCLUSION & WAY FORWARD

# %% [markdown]
# ---

# %% [markdown]
# **STEP 1: IMPORT DATA** <br />
# Main Datasets published by John Hopkins can be obtained here: <br />
# https://github.com/Zamani-AB/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Zamani-AB/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/13/20  12/14/20  12/15/20  \
# 0        0        0        0        0  ...     48527     48718     48952
# 1        0        0        0        0  ...     48530     49191     50000
# 2        0        0        0        0  ...     92102     92597     93065
# 3        0        0        0        0  ...      7338      7382      7382
# 4        0        0        0        0  ...     16188     16277     16362
#
#    12/16/20  12/17/20  12/18/20  12/19/20  12/20/20  12/21/20  12/22/20
# ...

# %% [markdown]
# ---

# %% [markdown]
# **Step 2: Data Processing** <br />
# (Require data blending of main dataset with **"Human Development Index (HDI)"** datasets publicly available, published by United Nation. Data can be obtained here: https://github.com/Zamani-AB/COVID-19/blob/master/HDI.csv)

# %% [markdown]
# 1. Exploratory Data Analysis (EDA) was conducted for initial assessment of the raw data obtained, utilizing Orange Data Mining tool. It was understood that data are being distributed accross multiple regions and countries based on the Scatter Plot.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Using only the main datasets might not be sufficient for analytics purpose. Hence, **"Human Development Index (HDI)"** were obtained and use for data blending with the main dataset, in particular to make use of "Total population" field.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For this purpose, the following workflow shows diagram on feature constructor by to create "cases per million" by taking number of cases and dividing them with total population
#
# ![image.png](attachment:image.png)
